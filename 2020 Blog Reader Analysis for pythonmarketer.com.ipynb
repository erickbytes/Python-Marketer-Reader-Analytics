# %% [markdown]
# # Introduction
# This is a retrospective on my blog's performance in 2020. It was a huge year, readers were up on 10x over December 2019! Here's a look at where people are reading, my most resonant works this year \ writing tendencies and how readers found my blog.
#
# # Table of Contents
# 1. Where in the world do people read about python?
# 2. Most Read Posts in 2020
# 3. Top Reader Referral Sources
# 4. Reflections and Notes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.style.use('seaborn-pastel')
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Where in the world do people read about python? - pythonmarketer.com

# %%
url = 'https://raw.githubusercontent.com/erickbytes/Python-Marketer-Reader-Analytics/master/dataset/pythonmarketer.com_countryviews_year_01_01_2020_12_31_2020.csv'
readers = pd.read_csv(url, names=['country','views'])
readers.head()
# Out:
#           country  views
# 0   United States   1312
# 1          Mexico    622
# 2           India    467
# 3         Germany    209
# 4  United Kingdom    171

# %%
readers.describe()
# Out:
#              views
# count   119.000000
# mean     39.126050
# std     140.037256
# min       1.000000
# 25%       2.000000
# 50%       5.000000
# 75%      25.000000
# max    1312.000000

# %%
readers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  119 non-null    object
#  1   views    119 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.0+ KB

# %%
# top 25 views by country in 2020 on pythonmarketer.com
readers.nlargest(25, 'views')
# Out:
#                 country  views
# 0         United States   1312
# 1                Mexico    622
# 2                 India    467
# 3               Germany    209
# 4        United Kingdom    171
# 5                France    127
# 6                 China    126
# 7                Canada    110
# 8                Brazil     80
# 9                Sweden     67
# 10            Australia     62
# 11                Italy     62
# 12          Netherlands     51
# 13            Indonesia     50
# 14          South Korea     50
# 15             Thailand     50
# 16               Russia     48
# 17                Spain     48
# 18            Singapore     38
# 19         South Africa     38
# 20          Switzerland     37
# 21                Japan     36
# 22              Vietnam     35
# 23  Hong Kong SAR China     29
# 24               Israel     28

# %% [markdown]
# ## Most Read Posts in 2020 - pythonmarketer.com

# %%
url = 'https://github.com/erickbytes/Python-Marketer-Reader-Analytics/blob/master/dataset/2020_pythonmarketer.com_post_views.xlsx?raw=true.xlsx'
posts = pd.read_excel(url)
posts.head()
# Out:
#                                                                          name  \
# 0                                                        Home page / Archives
# 1                                                Gooey GUI for Python Scripts
# 2  Inserting New Rows Into A Microsoft Access Database With Python and pyodbc
# 3             How to Install Libraries and Enable the pip Installer in Python
# 4            Making A Desktop Color Eyedropper in Python to Grab Color Values
#
#    views  \
# 0   1013
# 1    610
# 2    594
# 3    579
# 4    226
#
#                                                                                                                    url
# 0                                                                                          https://pythonmarketer.com/
# 1                                        https://pythonmarketer.wordpress.com/2018/08/25/gooey-gui-for-python-scripts/
# ...

# %%
# extract date each post was published from post urls
posts['date'] = posts.url.str.split(pat='/', n=6).apply(lambda url:[x for x in url if x.isdigit()])
posts.date = pd.to_datetime(posts.date.str.join('-'))
posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    55 non-null     object
#  1   views   55 non-null     int64
#  2   url     55 non-null     object
#  3   date    54 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 1.8+ KB

# %%
# Top 25 most viewed posts in 2020
posts.nlargest(25, 'views')
# Out:
#                                                                                                name  \
# 0                                                                              Home page / Archives
# 1                                                                      Gooey GUI for Python Scripts
# 2                        Inserting New Rows Into A Microsoft Access Database With Python and pyodbc
# 3                                   How to Install Libraries and Enable the pip Installer in Python
# 4                                  Making A Desktop Color Eyedropper in Python to Grab Color Values
# 5                                           Integrating MySQL with Flask, pandas and pythonanywhere
# 6                                                          Findstr, RegEx File Searches for Windows
# 7                     Automating pytest on Windows with a .bat file, Python, Task Scheduler and Box
# ...

# %%
# posts by year published since I began writing in 2016
ax = (posts.date.dt.year.fillna(0).astype(int)
                                  .value_counts(sort=False)
                                  .drop([0])
                                  .plot(kind='bar', rot=45, title='pythonmarketer.com Posts By Year Published'))
ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))

# %% [markdown]
# **Historically, spring has been my most productive season of writing.**

# %%
# Historically, August, May, April and March are tied for most posts.
months = ['January', 'February', 'March', 'April', 'May', 'June', 
          'July','August','September','October','November','December']
posts_by_month = (posts.date.dt.month
                        .fillna(0)
                        .astype(int)
                        .value_counts(sort=False))
      
ax = posts_by_month.plot(kind='bar',
                         rot=45,
                         xticks=posts_by_month.index,
                         title='Posts Published by Month on pythonmarketer.com - 2016-2020')
ax.set_xticklabels(months)
ax

# %%
# top 25 most viewed posts by year published
(posts.nlargest(25, 'views').date.dt.year.fillna(0)
                                         .astype(int)
                                         .value_counts(sort=False)
                                         .drop([0])
                                         .plot(kind='bar', rot=45, title='pythonmarketer.com Most Read Posts, Year Published'))

# %%
# plot 2020 page views based on the date the post viewed was published
posts = posts.sort_values(['date'])
plt.plot_date(x=posts.date, y=posts.views, markersize=10)
plt.title('Posts Viewed in 2020 Vs. Date Published - pythonmarketer.com')
# Out:
# Text(0.5, 1.0, 'Posts Viewed in 2020 Vs. Date Published - pythonmarketer.com')

# %% [markdown]
# # pythonmarketer.com View Referral Sources
# Most readers find pythonmarketer.com through search engines like duckduckgo.com, Google, Bing, Yahoo! and Baidu to name a few of them. qwant.com, for example (15 views), is a French search engine.

# %%
url = 'https://raw.githubusercontent.com/erickbytes/Python-Marketer-Reader-Analytics/master/dataset/pythonmarketer.com_referrers_year_01_01_2020_12_31_2020.csv'
referrers = pd.read_csv(url, names=['source','views'])
referrers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   source  103 non-null    object
#  1   views   103 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 1.7+ KB

# %%
referrers.sort_values('views', ascending=False).reset_index(drop=True).head(50)
# Out:
#                                                                                                                                                                                                                                                                                         source  \
# 0                                                                                                                                                                                                                                                                               Search Engines
# 1                                                                                                                                                                                                                                                               Search Engines > Google Search
# ...

# %%
ax = referrers.nlargest(10, 'views').plot(kind='barh', title='Top 10 Referral Sources - pythonmarketer.com')
sources = list(referrers.nlargest(10, 'views').source)
ax.set_yticklabels(sources)
plt.gca().invert_yaxis()

# %% [markdown]
# # Reflections and Notes
# - It took a few years of writing posts before gaining traction! Seeing more readers nowadays which is always desirable.
# - 2018 and 2020 were strong years in terms of increasing both posts published and readers.
# - Data was exported to .csv through Wordpress blogging platform analytics
# - Approximately 3,200 humans from 119 countries read about python on pythonmarketer.com in 2020. That's pretty rad, world. Let's keep learning!
